# %% [markdown]
# # TRANSACTIONS DATASET EXPLORATION USING PYTHON

# %% [markdown]
# # 💳 Transactions Data Validation
#
# This notebook focuses on validating the transactions dataset used in the Coffee Shop BI project.
#
# The objective is to ensure data integrity, consistency, and readiness for further processing in Power BI.

# %% [markdown]
# #### Installation of pandas and import pandas and os

# %%
# !pip install pandas
import os
import pandas as pd
# Out:
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: C:\Users\keren mayer\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# ## 1. Data Loading

# %% [markdown]
# #### Inspecting available sheets in the Excel file

# %%
file_path = "OneDrive/Documents/Bureau/EXPERIS/FINAL BI PROJECT/data/Coffee Shop Sales (2)good.xlsx"

xls = pd.ExcelFile(file_path)
xls.sheet_names
# Out:
# ['Pivot Tables', 'Dashboard', 'Transactions']

# %% [markdown]
# #### Loading a specific sheet from the Excel file

# %%
df = pd.read_excel(file_path, sheet_name="Transactions")
df.head()
# Out:
#    transaction_id transaction_date transaction_time  transaction_qty  \
# 0               1       2023-01-01         07:06:11                2
# 1               2       2023-01-01         07:08:56                2
# 2               3       2023-01-01         07:14:04                2
# 3               4       2023-01-01         07:20:24                1
# 4               5       2023-01-01         07:22:41                2
#
#    store_id   store_location  product_id  unit_price    product_category  \
# 0         5  Lower Manhattan          32         3.0              Coffee
# 1         5  Lower Manhattan          57         3.1                 Tea
# 2         5  Lower Manhattan          59         4.5  Drinking Chocolate
# 3         5  Lower Manhattan          22         2.0              Coffee
# 4         5  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail  Revenue  Month Month.1  \
# ...

# %% [markdown]
# ## 2. Initial Data Exploration

# %% [markdown]
# #### Inspecting the overall structure of the dataset

# %%
df.shape
# Out:
# (149116, 17)

# %% [markdown]
# #### Reviewing column names and dataset schema

# %%
df.columns
# Out:
# Index(['transaction_id', 'transaction_date', 'transaction_time',
#        'transaction_qty', 'store_id', 'store_location', 'product_id',
#        'unit_price', 'product_category', 'product_type', 'product_detail',
#        'Revenue', 'Month', 'Month.1', 'Weekday', 'Weekday.1', 'Hour'],
#       dtype='object')

# %% [markdown]
# ## 3. Data Structure Analysis

# %% [markdown]
# #### Checking data types and completeness of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   transaction_date  149116 non-null  datetime64[ns]
#  2   transaction_time  149116 non-null  object
#  3   transaction_qty   149116 non-null  int64
#  4   store_id          149116 non-null  int64
#  5   store_location    149116 non-null  object
#  6   product_id        149116 non-null  int64
#  7   unit_price        149116 non-null  float64
#  8   product_category  149116 non-null  object
#  9   product_type      149116 non-null  object
#  10  product_detail    149116 non-null  object
#  11  Revenue           149116 non-null  float64
#  12  Month             149116 non-null  int64
#  13  Month.1           149116 non-null  object
#  14  Weekday           149116 non-null  int64
# ...

# %% [markdown]
# ## 4. Missing Values Analysis

# %% [markdown]
# #### Assessing missing values across all columns

# %%
df.isnull().sum()
# Out:
# transaction_id      0
# transaction_date    0
# transaction_time    0
# transaction_qty     0
# store_id            0
# store_location      0
# product_id          0
# unit_price          0
# product_category    0
# product_type        0
# product_detail      0
# Revenue             0
# Month               0
# Month.1             0
# Weekday             0
# Weekday.1           0
# Hour                0
# dtype: int64

# %% [markdown]
# ## 5. Duplicate Records Check

# %% [markdown]
# #### Checking for duplicate transactions

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No duplicate transactions detected.

# %% [markdown]
# ## 6. Revenue Consistency Check

# %% [markdown]
# #### Validating revenue consistency

# %%
(df["transaction_qty"] * df["unit_price"] - df["Revenue"]).abs().describe()
# Out:
# count    149116.0
# mean          0.0
# std           0.0
# min           0.0
# 25%           0.0
# 50%           0.0
# 75%           0.0
# max           0.0
# dtype: float64

# %% [markdown]
# Revenue calculation is consistent across the dataset.

# %% [markdown]
# ## 6. Statistical Summary of Key Metrics
#
# This section reviews the distribution of key numerical variables:
# - transaction quantity
# - unit price
# - revenue
#
# The goal is to identify potential anomalies or inconsistencies in the data.

# %%
# decsribe generate decriptive statistics
df[["transaction_qty", "unit_price", "Revenue"]].describe()
# Out:
#        transaction_qty     unit_price        Revenue
# count    149116.000000  149116.000000  149116.000000
# mean          1.438276       3.382219       4.686367
# std           0.542509       2.658723       4.227099
# min           1.000000       0.800000       0.800000
# 25%           1.000000       2.500000       3.000000
# 50%           1.000000       3.000000       3.750000
# 75%           2.000000       3.750000       6.000000
# max           8.000000      45.000000     360.000000

# %% [markdown]
# ### Key Observations
#
# - Transaction quantity is generally low (median = 1), indicating most purchases are single items
# - Unit prices vary significantly, suggesting a mix of low-cost and premium products
# - Revenue distribution is consistent with quantity × price logic
# - Maximum values appear reasonable (no extreme outliers detected)
#
# Overall, the dataset shows consistent and realistic value ranges.

# %%
df.sample(17)
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 104055          104309       2023-05-22         14:55:40                2
# 54750            54861       2023-03-31         14:18:19                1
# 63110            63280       2023-04-10         18:20:59                1
# 45187            45294       2023-03-17         12:03:34                1
# 65470            65640       2023-04-13         12:19:33                1
# 21052            21109       2023-02-07         16:17:15                1
# 61357            61527       2023-04-08         19:24:28                2
# 105132          105386       2023-05-23         14:43:50                2
# 137733          138070       2023-06-21         08:15:56                1
# 126157          126494       2023-06-11         13:45:06                1
# 37600            37657       2023-03-06         19:55:59                2
# 42225            42332       2023-03-13         10:56:57                1
# ...

# %% [markdown]
# ## 8. Conclusion
#
# - Dataset contains 149116 transactions across multiple locations
# - No critical missing values detected
# - No duplicate records found
# - Revenue calculations are consistent
# - Data is clean and ready for BI analysis
